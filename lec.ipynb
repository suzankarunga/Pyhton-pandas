# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
suzan = pd.read_csv(r'C:\Users\Suzan\Desktop\sem 3\datasets\data\dirty_data.csv')

# %%
suzan.head(20)
# Out:
#                    date            station  PRCP   SNOW  SNWD    TMAX  TMIN  \
# 0   2018-01-01T00:00:00                  ?   0.0    0.0  -inf  5505.0 -40.0
# 1   2018-01-01T00:00:00                  ?   0.0    0.0  -inf  5505.0 -40.0
# 2   2018-01-01T00:00:00                  ?   0.0    0.0  -inf  5505.0 -40.0
# 3   2018-01-02T00:00:00  GHCND:USC00280907   0.0    0.0  -inf    -8.3 -16.1
# 4   2018-01-03T00:00:00  GHCND:USC00280907   0.0    0.0  -inf    -4.4 -13.9
# 5   2018-01-03T00:00:00  GHCND:USC00280907   0.0    0.0  -inf    -4.4 -13.9
# 6   2018-01-03T00:00:00  GHCND:USC00280907   0.0    0.0  -inf    -4.4 -13.9
# 7   2018-01-04T00:00:00                  ?  20.6  229.0   inf  5505.0 -40.0
# 8   2018-01-04T00:00:00                  ?  20.6  229.0   inf  5505.0 -40.0
# 9   2018-01-05T00:00:00                  ?   0.3    NaN   NaN  5505.0 -40.0
# 10  2018-01-05T00:00:00                  ?   0.3    NaN   NaN  5505.0 -40.0
# ...

# %%
suzan.dtypes
# Out:
# date                  object
# station               object
# PRCP                 float64
# SNOW                 float64
# SNWD                 float64
# TMAX                 float64
# TMIN                 float64
# TOBS                 float64
# WESF                 float64
# inclement_weather     object
# dtype: object

# %%
suzan.isnull
# Out:
# <bound method DataFrame.isnull of                     date            station  PRCP  SNOW  SNWD    TMAX  TMIN  \
# 0    2018-01-01T00:00:00                  ?   0.0   0.0  -inf  5505.0 -40.0
# 1    2018-01-01T00:00:00                  ?   0.0   0.0  -inf  5505.0 -40.0
# 2    2018-01-01T00:00:00                  ?   0.0   0.0  -inf  5505.0 -40.0
# 3    2018-01-02T00:00:00  GHCND:USC00280907   0.0   0.0  -inf    -8.3 -16.1
# 4    2018-01-03T00:00:00  GHCND:USC00280907   0.0   0.0  -inf    -4.4 -13.9
# ..                   ...                ...   ...   ...   ...     ...   ...
# 760  2018-12-31T00:00:00  GHCND:USC00280907   0.0   0.0  -inf     3.3  -3.3
# 761  2018-12-31T00:00:00  GHCND:USC00280907   0.0   0.0  -inf     3.3  -3.3
# 762  2018-12-31T00:00:00  GHCND:USC00280907   0.0   0.0  -inf     3.3  -3.3
# 763  2018-12-31T00:00:00                  ?   0.0   0.0  -inf  5505.0 -40.0
# 764  2018-12-31T00:00:00                  ?   0.0   0.0  -inf  5505.0 -40.0
#
# ...

# %%
suzan.isnull()
# Out:
#       date  station   PRCP   SNOW   SNWD   TMAX   TMIN   TOBS  WESF  \
# 0    False    False  False  False  False  False  False   True  True
# 1    False    False  False  False  False  False  False   True  True
# 2    False    False  False  False  False  False  False   True  True
# 3    False    False  False  False  False  False  False  False  True
# 4    False    False  False  False  False  False  False  False  True
# ..     ...      ...    ...    ...    ...    ...    ...    ...   ...
# 760  False    False  False  False  False  False  False  False  True
# 761  False    False  False  False  False  False  False  False  True
# 762  False    False  False  False  False  False  False  False  True
# 763  False    False  False  False  False  False  False   True  True
# 764  False    False  False  False  False  False  False   True  True
#
#      inclement_weather
# 0                 True
# 1                 True
# 2                 True
# 3                False
# 4                False
# ...

# %%
suzan.isnull().sum
# Out:
# <bound method DataFrame.sum of       date  station   PRCP   SNOW   SNWD   TMAX   TMIN   TOBS  WESF  \
# 0    False    False  False  False  False  False  False   True  True
# 1    False    False  False  False  False  False  False   True  True
# 2    False    False  False  False  False  False  False   True  True
# 3    False    False  False  False  False  False  False  False  True
# 4    False    False  False  False  False  False  False  False  True
# ..     ...      ...    ...    ...    ...    ...    ...    ...   ...
# 760  False    False  False  False  False  False  False  False  True
# 761  False    False  False  False  False  False  False  False  True
# 762  False    False  False  False  False  False  False  False  True
# 763  False    False  False  False  False  False  False   True  True
# 764  False    False  False  False  False  False  False   True  True
#
#      inclement_weather
# 0                 True
# 1                 True
# 2                 True
# ...

# %%
suzan.isnull().sum()
# Out:
# date                   0
# station                0
# PRCP                   0
# SNOW                 188
# SNWD                 188
# TMAX                   0
# TMIN                   0
# TOBS                 367
# WESF                 754
# inclement_weather    357
# dtype: int64

# %%
suzan.drop(columns=['station'],inplace=True)

# %%
suzan.head()
# Out:
#                   date  PRCP  SNOW  SNWD    TMAX  TMIN  TOBS  WESF  \
# 0  2018-01-01T00:00:00   0.0   0.0  -inf  5505.0 -40.0   NaN   NaN
# 1  2018-01-01T00:00:00   0.0   0.0  -inf  5505.0 -40.0   NaN   NaN
# 2  2018-01-01T00:00:00   0.0   0.0  -inf  5505.0 -40.0   NaN   NaN
# 3  2018-01-02T00:00:00   0.0   0.0  -inf    -8.3 -16.1 -12.2   NaN
# 4  2018-01-03T00:00:00   0.0   0.0  -inf    -4.4 -13.9 -13.3   NaN
#
#   inclement_weather
# 0               NaN
# 1               NaN
# 2               NaN
# 3             False
# 4             False

# %%
suzan[['SNOW','PRCP']] = suzan[['SNOW', 'PRCP']].fillna(suzan[['SNOW', 'PRCP']].mean())

# %%
suzan.head(10)
# Out:
#                   date  PRCP        SNOW  SNWD    TMAX  TMIN  TOBS  WESF  \
# 0  2018-01-01T00:00:00   0.0    0.000000  -inf  5505.0 -40.0   NaN   NaN
# 1  2018-01-01T00:00:00   0.0    0.000000  -inf  5505.0 -40.0   NaN   NaN
# 2  2018-01-01T00:00:00   0.0    0.000000  -inf  5505.0 -40.0   NaN   NaN
# 3  2018-01-02T00:00:00   0.0    0.000000  -inf    -8.3 -16.1 -12.2   NaN
# 4  2018-01-03T00:00:00   0.0    0.000000  -inf    -4.4 -13.9 -13.3   NaN
# 5  2018-01-03T00:00:00   0.0    0.000000  -inf    -4.4 -13.9 -13.3   NaN
# 6  2018-01-03T00:00:00   0.0    0.000000  -inf    -4.4 -13.9 -13.3   NaN
# 7  2018-01-04T00:00:00  20.6  229.000000   inf  5505.0 -40.0   NaN  19.3
# 8  2018-01-04T00:00:00  20.6  229.000000   inf  5505.0 -40.0   NaN  19.3
# 9  2018-01-05T00:00:00   0.3    4.202773   NaN  5505.0 -40.0   NaN   NaN
#
#   inclement_weather
# 0               NaN
# 1               NaN
# 2               NaN
# 3             False
# 4             False
# 5             False
# ...
