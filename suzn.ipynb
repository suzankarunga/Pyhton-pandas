# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.0-cp311-cp311-win_amd64.whl (11.6 MB)
# ...
#                                               0.0/15.8 MB ? eta -:--:--
#                                               0.0/15.8 MB ? eta -:--:--
#                                               0.0/15.8 MB ? eta -:--:--
#                                               0.0/15.8 MB ? eta -:--:--
#                                              0.1/15.8 MB 393.8 kB/s eta 0:00:40
#                                              0.1/15.8 MB 435.7 kB/s eta 0:00:37
#                                              0.1/15.8 MB 435.7 kB/s eta 0:00:37
#                                              0.1/15.8 MB 435.7 kB/s eta 0:00:37
#                                              0.1/15.8 MB 435.7 kB/s eta 0:00:37
#                                              0.1/15.8 MB 435.7 kB/s eta 0:00:37
#                                              0.1/15.8 MB 435.7 kB/s eta 0:00:37
# ...

# %%
pip install openpyxl
# Out:
# ...
#                                               0.0/250.0 kB ? eta -:--:--
#      -                                        10.2/250.0 kB ? eta -:--:--
#      -                                        10.2/250.0 kB ? eta -:--:--
#      -                                        10.2/250.0 kB ? eta -:--:--
#      ---------                             61.4/250.0 kB 363.1 kB/s eta 0:00:01
#      ----------------                     112.6/250.0 kB 467.6 kB/s eta 0:00:01
#      -----------------                    122.9/250.0 kB 423.5 kB/s eta 0:00:01
#      --------------------                 143.4/250.0 kB 448.2 kB/s eta 0:00:01
#      ----------------------               153.6/250.0 kB 416.7 kB/s eta 0:00:01
#      -------------------------            174.1/250.0 kB 419.0 kB/s eta 0:00:01
#      ----------------------------         194.6/250.0 kB 436.8 kB/s eta 0:00:01
#      ----------------------------         194.6/250.0 kB 436.8 kB/s eta 0:00:01
# ...

# %%
pip install numpy
# Out:
# ...
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'c:\\Python311\\Scripts\\f2py.exe' -> 'c:\\Python311\\Scripts\\f2py.exe.deleteme'
#
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#                                               0.0/15.8 MB ? eta -:--:--
#                                               0.0/15.8 MB ? eta -:--:--
#                                               0.0/15.8 MB ? eta -:--:--
#                                               0.0/15.8 MB ? eta -:--:--
#                                              0.1/15.8 MB 357.2 kB/s eta 0:00:45
#                                              0.1/15.8 MB 403.5 kB/s eta 0:00:39
#                                              0.1/15.8 MB 403.5 kB/s eta 0:00:39
# ...

# %%
pip install matplotlib
# Out:
# ...
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.1/7.6 MB 1.1 MB/s eta 0:00:07
#                                               0.1/7.6 MB 1.1 MB/s eta 0:00:08
#                                               0.1/7.6 MB 798.9 kB/s eta 0:00:10
#                                               0.1/7.6 MB 798.9 kB/s eta 0:00:10
#                                               0.2/7.6 MB 706.2 kB/s eta 0:00:11
#                                               0.2/7.6 MB 615.9 kB/s eta 0:00:13
#                                               0.2/7.6 MB 615.9 kB/s eta 0:00:13
#                                               0.2/7.6 MB 615.9 kB/s eta 0:00:13
#      -                                        0.2/7.6 MB 471.4 kB/s eta 0:00:16
# ...

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.0-cp311-cp311-win_amd64.whl (11.6 MB)
# ...
#                                               0.0/505.5 kB ? eta -:--:--
#                                               10.2/505.5 kB ? eta -:--:--
#      --                                    30.7/505.5 kB 325.1 kB/s eta 0:00:02
#      --                                    41.0/505.5 kB 217.9 kB/s eta 0:00:03
#      -----                                 71.7/505.5 kB 435.7 kB/s eta 0:00:01
#      -----                                 71.7/505.5 kB 435.7 kB/s eta 0:00:01
#      -----                                 71.7/505.5 kB 435.7 kB/s eta 0:00:01
#      --------                             112.6/505.5 kB 344.8 kB/s eta 0:00:02
#      --------                             112.6/505.5 kB 344.8 kB/s eta 0:00:02
#      --------                             112.6/505.5 kB 344.8 kB/s eta 0:00:02
#      --------                             112.6/505.5 kB 344.8 kB/s eta 0:00:02
# ...

# %%
pip install numpy matplotlib
# Out:
# ...
#   Using cached matplotlib-3.8.2-cp311-cp311-win_amd64.whl (7.6 MB)
# ...
#   Using cached contourpy-1.2.0-cp311-cp311-win_amd64.whl (187 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# ...
#
# ...
#                                               0.0/294.9 kB ? eta -:--:--
#                                               0.0/294.9 kB ? eta -:--:--
#                                               0.0/294.9 kB ? eta -:--:--
#      -----                                   41.0/294.9 kB 1.9 MB/s eta 0:00:01
#      -------                               61.4/294.9 kB 656.4 kB/s eta 0:00:01
#      -------                               61.4/294.9 kB 656.4 kB/s eta 0:00:01
#      -------                               61.4/294.9 kB 656.4 kB/s eta 0:00:01
#      -------                               61.4/294.9 kB 656.4 kB/s eta 0:00:01
#      -------                               61.4/294.9 kB 656.4 kB/s eta 0:00:01
#      -----------                           92.2/294.9 kB 249.8 kB/s eta 0:00:01
#      -----------                           92.2/294.9 kB 249.8 kB/s eta 0:00:01
#      -----------                           92.2/294.9 kB 249.8 kB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Suzan\AppData\Local\Temp\ipykernel_13636\3866030240.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
Suzan= pd.read_excel(r'C:\Users\Suzan\Downloads\datasets\data\EducationandIncome.xlsx', header=2)

# %%
Suzan.head()
# Out:
#    Gender    Age Level of Education  Gross Annual Income
# 0  Female  40-60    Graduate Degree                75000
# 1  Female  25-39  Bachelor's Degree                47000
# 2    Male  40-60    High School/GED                40000
# 3  Female  25-39       Some College                30000
# 4  Female  25-39       Some College                60000

# %%
Suzan.tail()
# Out:
#     Gender    Age Level of Education  Gross Annual Income
# 19  Female  25-39       Some College                15288
# 20    Male  25-39  Bachelor's Degree                58000
# 21  Female  18-24  Bachelor's Degree                10000
# 22  Female  25-39  Bachelor's Degree                85000
# 23    Male  18-24  Bachelor's Degree                20000

# %%
Suzan.shape
# Out:
# (24, 4)

# %%
Suzan.isnull()
# Out:
#     Gender    Age  Level of Education  Gross Annual Income
# 0    False  False               False                False
# 1    False  False               False                False
# 2    False  False               False                False
# 3    False  False               False                False
# 4    False  False               False                False
# 5    False  False               False                False
# 6    False  False               False                False
# 7    False  False               False                False
# 8    False  False               False                False
# 9    False  False               False                False
# 10   False  False               False                False
# 11   False  False               False                False
# 12   False  False               False                False
# 13   False  False               False                False
# 14   False  False               False                False
# ...

# %%
Suzan.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22     True
# 23    False
# dtype: bool

# %%
Suzan.duplicated().sum()
# Out:
# 1

# %%
Suzan['Age']
# Out:
# 0     40-60
# 1     25-39
# 2     40-60
# 3     25-39
# 4     25-39
# 5     40-60
# 6     25-39
# 7     25-39
# 8     25-39
# 9     40-60
# 10    40-60
# 11    18-24
# 12    25-39
# 13    25-39
# 14    40-60
# 15    25-39
# 16    25-39
# 17    25-39
# 18    25-39
# 19    25-39
# 20    25-39
# 21    18-24
# 22    25-39
# 23    18-24
# Name: Age, dtype: object

# %%
Suzan.head()
# Out:
#    Gender    Age Level of Education  Gross Annual Income
# 0  Female  40-60    Graduate Degree                75000
# 1  Female  25-39  Bachelor's Degree                47000
# 2    Male  40-60    High School/GED                40000
# 3  Female  25-39       Some College                30000
# 4  Female  25-39       Some College                60000

# %%
Suzan[['Age', 'Gender', 'Level of Education']]
# Out:
#       Age  Gender Level of Education
# 0   40-60  Female    Graduate Degree
# 1   25-39  Female  Bachelor's Degree
# 2   40-60    Male    High School/GED
# 3   25-39  Female       Some College
# 4   25-39  Female       Some College
# 5   40-60  Female  Bachelor's Degree
# 6   25-39  Female  Bachelor's Degree
# 7   25-39  Female  Bachelor's Degree
# 8   25-39    Male  Bachelor's Degree
# 9   40-60  Female  Bachelor's Degree
# 10  40-60  Female    Graduate Degree
# 11  18-24  Female       Some College
# 12  25-39  Female  Bachelor's Degree
# 13  25-39    Male  Bachelor's Degree
# 14  40-60    Male    Graduate Degree
# 15  25-39  Female  Associates Degree
# 16  25-39    Male    High School/GED
# 17  25-39    Male       Some College
# 18  25-39    Male    Graduate Degree
# 19  25-39  Female       Some College
# 20  25-39    Male  Bachelor's Degree
# 21  18-24  Female  Bachelor's Degree
# 22  25-39  Female  Bachelor's Degree
# 23  18-24    Male  Bachelor's Degree

# %%
Suzan['Gross Annual Income']
# Out:
# 0      75000
# 1      47000
# 2      40000
# 3      30000
# 4      60000
# 5      80000
# 6      10000
# 7      43000
# 8     130000
# 9      89000
# 10     50000
# 11     13462
# 12     85000
# 13     60000
# 14    200000
# 15     44000
# 16     26000
# 17     46100
# 18     15000
# 19     15288
# 20     58000
# 21     10000
# 22     85000
# 23     20000
# Name: Gross Annual Income, dtype: int64

# %%
Suzan['Gross Annual Income'].mean()
# Out:
# 55493.75

# %%
Suzan['Gross Annual Income'].max()
# Out:
# 200000

# %%
Suzan['Gross Annual Income'].min()
# Out:
# 10000

# %%
Suzan['Gross Annual Income'].median()
# Out:
# 46550.0

# %%
Suzan['Gross Annual Income'].mode()
# Out:
# 0    10000
# 1    60000
# 2    85000
# Name: Gross Annual Income, dtype: int64

# %%
Suzan['Gross Annual Income'].std()
# Out:
# 43231.33296605298

# %%
Suzan['Gross Annual Income'].describe()
# Out:
# count        24.000000
# mean      55493.750000
# std       43231.332966
# min       10000.000000
# 25%       24500.000000
# 50%       46550.000000
# 75%       76250.000000
# max      200000.000000
# Name: Gross Annual Income, dtype: float64

# %%
sns.barplot(x ='Gross Annual Income', y ='Age' , data=Suzan)
# Out:
# <Axes: xlabel='Gross Annual Income', ylabel='Age'>

# %%
sns.boxplot(x ='Age', y ='Level of Education' , data=Suzan)
# Out:
# <Axes: xlabel='Age', ylabel='Level of Education'>

# %%
sns.barplot(x ='Gross Annual Income', y ='Level of Education', data=Suzan)
# Out:
# <Axes: xlabel='Gross Annual Income', ylabel='Level of Education'>

# %%
Suzan['Gross Annual Income'].quantile(0.25)   #q1
# Out:
# 24500.0

# %%
Suzan['Gross Annual Income'].quantile(0.75)   #q3
# Out:
# 76250.0

# %%
Suzan['Gross Annual Income'].quantile(0.5)   #q2
# Out:
# 46550.0
